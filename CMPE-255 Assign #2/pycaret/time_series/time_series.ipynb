# %%
# !pip install pycaret

# %%
from pycaret import time_series as ts

# %%
import pandas as pd

# %%
from google.colab import files
da = files.upload()
# Out:
#      <input type="file" id="files-f5f94d0a-30b9-4fe1-942b-7a394b91cf3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5f94d0a-30b9-4fe1-942b-7a394b91cf3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('TSLA_cleaned_v2.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
data = df['Close']

# %% [markdown]
# **Environment**

# %%
s = setup(data=data, session_id=123, fold_strategy='rolling', fold=3, fh=30)
# Out:
# <style type="text/css">
# #T_a0f78_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a0f78" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f78_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a0f78_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0f78_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a0f78_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a0f78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0f78_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a0f78_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_a0f78_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# **Traning and comparing**

# %%
best_model = compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_30a73 th {
#   text-align: left;
# }
# ...

# %%
help(predict_model)
# Out:
# Help on function predict_model in module pycaret.time_series.forecasting.functional:
#
# predict_model(estimator, fh=None, X=None, return_pred_int=False, alpha: Optional[float] = None, coverage: Union[float, List[float]] = 0.9, round: int = 4, verbose: bool = True) -> pandas.core.frame.DataFrame
#     This function forecast using a trained model. When ``fh`` is None,
#     it forecasts using the same forecast horizon used during the
#     training.
#
#
#     Example
#     -------
#     >>> from pycaret.datasets import get_data
#     >>> airline = get_data('airline')
#     >>> from pycaret.time_series import *
#     >>> exp_name = setup(data = airline,  fh = 12)
#     >>> arima = create_model('arima')
#     >>> pred_holdout = predict_model(arima)
#     >>> pred_unseen = predict_model(finalize_model(arima), fh = 24)
#
#
#     estimator: sktime compatible object
#         Trained model object
#
#
#     fh: int, default = None
# ...

# %% [markdown]
# # **Predict**

# %%
future_predictions = predict_model(best_model, fh=30)
print(future_predictions)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d3ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d3ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9d3ef_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_9d3ef_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_9d3ef_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_9d3ef_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_9d3ef_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_9d3ef_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_9d3ef_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d3ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d3ef_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
# ...

# %% [markdown]
# # **Visualize prediction**

# %%
plot_model(best_model, plot='forecast')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
